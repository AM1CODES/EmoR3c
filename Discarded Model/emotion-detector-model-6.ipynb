# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2

# %%
train_dir = "../input/fer2013/train" #passing the path with training images
test_dir = "../input/fer2013/test"   #passing the path with testing images

# %%
img_size = 48 #original size of the image

# %%
"""
Data Augmentation
--------------------------
rotation_range = rotates the image with the amount of degrees we provide
width_shift_range = shifts the image randomly to the right or left along the width of the image
height_shift range = shifts image randomly to up or below along the height of the image
horizontal_flip = flips the image horizontally
rescale = to scale down the pizel values in our image between 0 and 1
zoom_range = applies random zoom to our object
validation_split = reserves some images to be used for validation purpose
"""

train_datagen = ImageDataGenerator(rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

# %%
"""
Applying data augmentation to the images as we read 
them from their respectivve directories
"""
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                             )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
"""
Modeling
"""

model = Sequential()
model.add(Conv2D(filters = 32,kernel_size = (3,3),padding = 'same',activation = 'relu',input_shape = (img_size,img_size,1)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Conv2D(filters = 64,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 512,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 512,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Flatten())
model.add(Dense(units = 128,activation = 'relu',kernel_initializer='normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(units = 256,activation = 'relu',kernel_initializer='normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(units = 512,activation = 'relu',kernel_initializer='normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(7,activation = 'softmax'))

# %%
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
optimizer = Adam(lr = 0.001)
model.compile(loss = "categorical_crossentropy",optimizer = optimizer,metrics = ['accuracy'])
epochs = 70
batch_size = 64

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 512)         590336
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 3, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               65664
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 3,285,255
# Trainable params: 3,280,967
# Non-trainable params: 4,288
# _________________________________________________________________

# %%
history = model.fit(x = train_generator,steps_per_epoch = 22968//64,epochs = epochs,validation_data = validation_generator,validation_steps = 1432//64)
# Out:
# Epoch 1/70
# 358/358 [==============================] - 118s 320ms/step - loss: 2.3266 - accuracy: 0.1923 - val_loss: 2.5357 - val_accuracy: 0.1719
# Epoch 2/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.9043 - accuracy: 0.2289 - val_loss: 1.8282 - val_accuracy: 0.2443
# Epoch 3/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.8438 - accuracy: 0.2500 - val_loss: 1.8031 - val_accuracy: 0.2670
# Epoch 4/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.8114 - accuracy: 0.2651 - val_loss: 1.7980 - val_accuracy: 0.2614
# Epoch 5/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.7869 - accuracy: 0.2720 - val_loss: 2.3698 - val_accuracy: 0.2322
# Epoch 6/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.7648 - accuracy: 0.2793 - val_loss: 1.6825 - val_accuracy: 0.3274
# Epoch 7/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.7232 - accuracy: 0.3056 - val_loss: 1.8138 - val_accuracy: 0.2741
# Epoch 8/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.7022 - accuracy: 0.3227 - val_loss: 1.6922 - val_accuracy: 0.3040
# Epoch 9/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.6699 - accuracy: 0.3334 - val_loss: 1.6649 - val_accuracy: 0.3551
# Epoch 10/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.6193 - accuracy: 0.3625 - val_loss: 1.6995 - val_accuracy: 0.3707
# Epoch 11/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.5881 - accuracy: 0.3807 - val_loss: 1.6745 - val_accuracy: 0.3274
# Epoch 12/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.5661 - accuracy: 0.3891 - val_loss: 1.5256 - val_accuracy: 0.4112
# Epoch 13/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.5301 - accuracy: 0.4018 - val_loss: 1.5337 - val_accuracy: 0.4105
# Epoch 14/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.5210 - accuracy: 0.4083 - val_loss: 1.5698 - val_accuracy: 0.4091
# Epoch 15/70
# 358/358 [==============================] - 26s 72ms/step - loss: 1.4749 - accuracy: 0.4352 - val_loss: 1.4424 - val_accuracy: 0.4616
# Epoch 16/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.4770 - accuracy: 0.4279 - val_loss: 1.4519 - val_accuracy: 0.4489
# Epoch 17/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.4519 - accuracy: 0.4345 - val_loss: 1.4318 - val_accuracy: 0.4439
# Epoch 18/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.4269 - accuracy: 0.4523 - val_loss: 1.4467 - val_accuracy: 0.4503
# Epoch 19/70
# 358/358 [==============================] - 27s 76ms/step - loss: 1.4275 - accuracy: 0.4498 - val_loss: 1.3539 - val_accuracy: 0.4744
# Epoch 20/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.4165 - accuracy: 0.4551 - val_loss: 1.6360 - val_accuracy: 0.3800
# Epoch 21/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.4043 - accuracy: 0.4554 - val_loss: 1.7894 - val_accuracy: 0.4332
# Epoch 22/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.3980 - accuracy: 0.4638 - val_loss: 1.6361 - val_accuracy: 0.3636
# Epoch 23/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.3884 - accuracy: 0.4680 - val_loss: 1.3588 - val_accuracy: 0.4716
# Epoch 24/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.3766 - accuracy: 0.4729 - val_loss: 1.3913 - val_accuracy: 0.4467
# Epoch 25/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.3601 - accuracy: 0.4800 - val_loss: 1.3078 - val_accuracy: 0.4858
# Epoch 26/70
# 358/358 [==============================] - 26s 72ms/step - loss: 1.3546 - accuracy: 0.4744 - val_loss: 1.3192 - val_accuracy: 0.4780
# Epoch 27/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.3353 - accuracy: 0.4879 - val_loss: 1.2987 - val_accuracy: 0.4986
# Epoch 28/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.3499 - accuracy: 0.4816 - val_loss: 1.6752 - val_accuracy: 0.3537
# Epoch 29/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.3250 - accuracy: 0.4901 - val_loss: 1.3531 - val_accuracy: 0.4865
# Epoch 30/70
# 358/358 [==============================] - 26s 72ms/step - loss: 1.3426 - accuracy: 0.4825 - val_loss: 1.2819 - val_accuracy: 0.5170
# Epoch 31/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.3381 - accuracy: 0.4891 - val_loss: 1.2926 - val_accuracy: 0.5092
# Epoch 32/70
# 358/358 [==============================] - 30s 83ms/step - loss: 1.3021 - accuracy: 0.5057 - val_loss: 1.2477 - val_accuracy: 0.5185
# Epoch 33/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.3047 - accuracy: 0.5044 - val_loss: 1.2793 - val_accuracy: 0.4915
# Epoch 34/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.2953 - accuracy: 0.5056 - val_loss: 1.2509 - val_accuracy: 0.5178
# Epoch 35/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.2987 - accuracy: 0.5021 - val_loss: 1.2109 - val_accuracy: 0.5163
# Epoch 36/70
# 358/358 [==============================] - 30s 83ms/step - loss: 1.2901 - accuracy: 0.5119 - val_loss: 1.2857 - val_accuracy: 0.5028
# Epoch 37/70
# 358/358 [==============================] - 29s 81ms/step - loss: 1.2954 - accuracy: 0.5057 - val_loss: 1.3824 - val_accuracy: 0.4666
# Epoch 38/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2817 - accuracy: 0.5092 - val_loss: 1.2282 - val_accuracy: 0.5170
# Epoch 39/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2805 - accuracy: 0.5126 - val_loss: 1.2538 - val_accuracy: 0.5156
# Epoch 40/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.2759 - accuracy: 0.5156 - val_loss: 1.2454 - val_accuracy: 0.5327
# Epoch 41/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2680 - accuracy: 0.5144 - val_loss: 1.1878 - val_accuracy: 0.5497
# Epoch 42/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.2701 - accuracy: 0.5154 - val_loss: 1.3675 - val_accuracy: 0.4631
# Epoch 43/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2512 - accuracy: 0.5226 - val_loss: 1.1779 - val_accuracy: 0.5391
# Epoch 44/70
# 358/358 [==============================] - 27s 76ms/step - loss: 1.2449 - accuracy: 0.5238 - val_loss: 1.1964 - val_accuracy: 0.5369
# Epoch 45/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2720 - accuracy: 0.5128 - val_loss: 1.2311 - val_accuracy: 0.5369
# Epoch 46/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2526 - accuracy: 0.5187 - val_loss: 1.2198 - val_accuracy: 0.5433
# Epoch 47/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.2452 - accuracy: 0.5283 - val_loss: 1.2200 - val_accuracy: 0.5348
# Epoch 48/70
# 358/358 [==============================] - 27s 76ms/step - loss: 1.2376 - accuracy: 0.5310 - val_loss: 1.1963 - val_accuracy: 0.5263
# Epoch 49/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2413 - accuracy: 0.5296 - val_loss: 1.2882 - val_accuracy: 0.5014
# Epoch 50/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.2242 - accuracy: 0.5297 - val_loss: 1.1320 - val_accuracy: 0.5625
# Epoch 51/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.2203 - accuracy: 0.5377 - val_loss: 1.1416 - val_accuracy: 0.5582
# Epoch 52/70
# 358/358 [==============================] - 31s 88ms/step - loss: 1.2354 - accuracy: 0.5261 - val_loss: 1.1921 - val_accuracy: 0.5455
# Epoch 53/70
# 358/358 [==============================] - 26s 72ms/step - loss: 1.2291 - accuracy: 0.5291 - val_loss: 1.1899 - val_accuracy: 0.5376
# Epoch 54/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.2278 - accuracy: 0.5325 - val_loss: 1.1415 - val_accuracy: 0.5682
# Epoch 55/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.2172 - accuracy: 0.5355 - val_loss: 1.1446 - val_accuracy: 0.5526
# Epoch 56/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.2106 - accuracy: 0.5407 - val_loss: 1.2176 - val_accuracy: 0.5398
# Epoch 57/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2101 - accuracy: 0.5416 - val_loss: 1.1461 - val_accuracy: 0.5632
# Epoch 58/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.2132 - accuracy: 0.5371 - val_loss: 1.1411 - val_accuracy: 0.5604
# Epoch 59/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2132 - accuracy: 0.5414 - val_loss: 1.1763 - val_accuracy: 0.5540
# Epoch 60/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2063 - accuracy: 0.5387 - val_loss: 1.1122 - val_accuracy: 0.5767
# Epoch 61/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.2006 - accuracy: 0.5425 - val_loss: 1.2011 - val_accuracy: 0.5376
# Epoch 62/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.1926 - accuracy: 0.5434 - val_loss: 1.1306 - val_accuracy: 0.5597
# Epoch 63/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.1941 - accuracy: 0.5480 - val_loss: 1.1416 - val_accuracy: 0.5511
# Epoch 64/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.1780 - accuracy: 0.5537 - val_loss: 1.1546 - val_accuracy: 0.5476
# Epoch 65/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.1827 - accuracy: 0.5500 - val_loss: 1.1504 - val_accuracy: 0.5540
# Epoch 66/70
# 358/358 [==============================] - 26s 74ms/step - loss: 1.1947 - accuracy: 0.5491 - val_loss: 1.1621 - val_accuracy: 0.5455
# Epoch 67/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.1816 - accuracy: 0.5513 - val_loss: 1.2166 - val_accuracy: 0.5334
# Epoch 68/70
# 358/358 [==============================] - 27s 75ms/step - loss: 1.1841 - accuracy: 0.5480 - val_loss: 1.1557 - val_accuracy: 0.5554
# Epoch 69/70
# 358/358 [==============================] - 27s 74ms/step - loss: 1.1850 - accuracy: 0.5505 - val_loss: 1.1429 - val_accuracy: 0.5675
# Epoch 70/70
# 358/358 [==============================] - 26s 73ms/step - loss: 1.1648 - accuracy: 0.5563 - val_loss: 1.1337 - val_accuracy: 0.5646

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('model_opt.h5')

# %%
img = image.load_img("../input/fer2013/test/surprise/PrivateTest_10089743.jpg",target_size = (48,48),color_mode = "grayscale")
img = np.array(img)
plt.imshow(img)
print(img.shape) #prints (48,48) that is the shape of our image
# Out:
# (48, 48)

# %%
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

# %%
img = np.expand_dims(img,axis = 0) #makes image shape (1,48,48)
img = img.reshape(1,48,48,1)
result = model.predict(img)
result = list(result[0])
print(result)
# Out:
# [6.6346074e-05, 0.0, 0.9999336, 0.0, 0.0, 0.0, 0.0]

# %%
img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# Fear
