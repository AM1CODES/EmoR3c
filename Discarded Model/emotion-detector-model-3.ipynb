# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2

# %%
train_dir = "../input/fer2013/train" #passing the path with training images
test_dir = "../input/fer2013/test"   #passing the path with testing images

# %%
img_size = 48 #original size of the image

# %%
"""
Data Augmentation
--------------------------
rotation_range = rotates the image with the amount of degrees we provide
width_shift_range = shifts the image randomly to the right or left along the width of the image
height_shift range = shifts image randomly to up or below along the height of the image
horizontal_flip = flips the image horizontally
rescale = to scale down the pizel values in our image between 0 and 1
zoom_range = applies random zoom to our object
validation_split = reserves some images to be used for validation purpose
"""

train_datagen = ImageDataGenerator(rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         zoom_range = 0.2,
                                         validation_split = 0.2
                                        )
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                         validation_split = 0.2)

# %%
"""
Applying data augmentation to the images as we read 
them from their respectivve directories
"""
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 64,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = validation_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 64,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                             )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
"""
Modeling
"""

model = Sequential()
model.add(Conv2D(filters = 32,kernel_size = (3,3),padding = 'same',activation = 'relu',input_shape = (img_size,img_size,1)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Conv2D(filters = 64,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Conv2D(filters = 256,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Conv2D(filters = 512,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = 2,strides = 2))

model.add(Flatten())
model.add(Dense(units = 128,activation = 'relu',kernel_initializer='normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(units = 64,activation = 'relu',kernel_initializer='normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(units = 32,activation = 'relu',kernel_initializer='normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(7,activation = 'softmax'))

# %%
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax
optimizer = Adam(lr = 0.001)
model.compile(loss = "categorical_crossentropy",optimizer = optimizer,metrics = ['accuracy'])
epochs = 70
batch_size = 64

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 48, 48, 32)        320
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 48, 48, 32)        128
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 6, 6, 256)         295168
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 3, 3, 512)         1180160
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               65664
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 7)                 231
# =================================================================
# Total params: 1,649,095
# Trainable params: 1,646,663
# Non-trainable params: 2,432
# _________________________________________________________________

# %%
history = model.fit(x = train_generator,steps_per_epoch = 22968//64,epochs = epochs,validation_data = validation_generator,validation_steps = 1432//64)
# Out:
# Epoch 1/70
# 358/358 [==============================] - 38s 102ms/step - loss: 2.2051 - accuracy: 0.1841 - val_loss: 1.9200 - val_accuracy: 0.1705
# Epoch 2/70
# 358/358 [==============================] - 35s 99ms/step - loss: 1.8713 - accuracy: 0.2280 - val_loss: 1.7764 - val_accuracy: 0.2699
# Epoch 3/70
# 358/358 [==============================] - 36s 99ms/step - loss: 1.8029 - accuracy: 0.2467 - val_loss: 1.7437 - val_accuracy: 0.2784
# Epoch 4/70
# 358/358 [==============================] - 36s 101ms/step - loss: 1.7603 - accuracy: 0.2736 - val_loss: 1.7907 - val_accuracy: 0.2812
# Epoch 5/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.7178 - accuracy: 0.2987 - val_loss: 1.8309 - val_accuracy: 0.2827
# Epoch 6/70
# 358/358 [==============================] - 37s 103ms/step - loss: 1.6802 - accuracy: 0.3236 - val_loss: 1.7372 - val_accuracy: 0.3118
# Epoch 7/70
# 358/358 [==============================] - 39s 109ms/step - loss: 1.6436 - accuracy: 0.3427 - val_loss: 1.6600 - val_accuracy: 0.3651
# Epoch 8/70
# 358/358 [==============================] - 38s 105ms/step - loss: 1.5790 - accuracy: 0.3852 - val_loss: 1.7657 - val_accuracy: 0.2784
# Epoch 9/70
# 358/358 [==============================] - 35s 99ms/step - loss: 1.5378 - accuracy: 0.4019 - val_loss: 1.5133 - val_accuracy: 0.4034
# Epoch 10/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.5125 - accuracy: 0.4118 - val_loss: 1.5845 - val_accuracy: 0.3942
# Epoch 11/70
# 358/358 [==============================] - 36s 99ms/step - loss: 1.4851 - accuracy: 0.4224 - val_loss: 1.5185 - val_accuracy: 0.3991
# Epoch 12/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.4672 - accuracy: 0.4298 - val_loss: 1.7656 - val_accuracy: 0.3118
# Epoch 13/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.4452 - accuracy: 0.4469 - val_loss: 1.4488 - val_accuracy: 0.4453
# Epoch 14/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.4284 - accuracy: 0.4470 - val_loss: 1.4090 - val_accuracy: 0.4560
# Epoch 15/70
# 358/358 [==============================] - 37s 103ms/step - loss: 1.4041 - accuracy: 0.4634 - val_loss: 1.3936 - val_accuracy: 0.4659
# Epoch 16/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.3916 - accuracy: 0.4701 - val_loss: 1.6123 - val_accuracy: 0.3707
# Epoch 17/70
# 358/358 [==============================] - 38s 106ms/step - loss: 1.3881 - accuracy: 0.4636 - val_loss: 1.3803 - val_accuracy: 0.4716
# Epoch 18/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.3741 - accuracy: 0.4726 - val_loss: 1.4298 - val_accuracy: 0.4375
# Epoch 19/70
# 358/358 [==============================] - 35s 97ms/step - loss: 1.3520 - accuracy: 0.4813 - val_loss: 1.3175 - val_accuracy: 0.4950
# Epoch 20/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.3515 - accuracy: 0.4807 - val_loss: 1.3051 - val_accuracy: 0.5014
# Epoch 21/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.3554 - accuracy: 0.4874 - val_loss: 1.5802 - val_accuracy: 0.3764
# Epoch 22/70
# 358/358 [==============================] - 36s 102ms/step - loss: 1.3305 - accuracy: 0.4922 - val_loss: 1.2703 - val_accuracy: 0.5121
# Epoch 23/70
# 358/358 [==============================] - 37s 105ms/step - loss: 1.3186 - accuracy: 0.4942 - val_loss: 1.4664 - val_accuracy: 0.4219
# Epoch 24/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.3342 - accuracy: 0.4913 - val_loss: 1.2909 - val_accuracy: 0.4993
# Epoch 25/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.3194 - accuracy: 0.4979 - val_loss: 1.2420 - val_accuracy: 0.5277
# Epoch 26/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.2990 - accuracy: 0.5060 - val_loss: 1.2540 - val_accuracy: 0.5142
# Epoch 27/70
# 358/358 [==============================] - 36s 99ms/step - loss: 1.2813 - accuracy: 0.5121 - val_loss: 1.2972 - val_accuracy: 0.4936
# Epoch 28/70
# 358/358 [==============================] - 36s 99ms/step - loss: 1.2729 - accuracy: 0.5153 - val_loss: 1.3097 - val_accuracy: 0.4858
# Epoch 29/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.2709 - accuracy: 0.5230 - val_loss: 1.4146 - val_accuracy: 0.4361
# Epoch 30/70
# 358/358 [==============================] - 35s 97ms/step - loss: 1.2735 - accuracy: 0.5171 - val_loss: 1.2425 - val_accuracy: 0.5227
# Epoch 31/70
# 358/358 [==============================] - 35s 97ms/step - loss: 1.2659 - accuracy: 0.5169 - val_loss: 1.3905 - val_accuracy: 0.4545
# Epoch 32/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.2537 - accuracy: 0.5260 - val_loss: 1.1885 - val_accuracy: 0.5483
# Epoch 33/70
# 358/358 [==============================] - 35s 99ms/step - loss: 1.2539 - accuracy: 0.5267 - val_loss: 1.2624 - val_accuracy: 0.5206
# Epoch 34/70
# 358/358 [==============================] - 37s 103ms/step - loss: 1.2460 - accuracy: 0.5265 - val_loss: 1.2813 - val_accuracy: 0.5092
# Epoch 35/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.2657 - accuracy: 0.5203 - val_loss: 1.1901 - val_accuracy: 0.5483
# Epoch 36/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.2463 - accuracy: 0.5341 - val_loss: 1.3640 - val_accuracy: 0.4659
# Epoch 37/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.2223 - accuracy: 0.5384 - val_loss: 1.2187 - val_accuracy: 0.5327
# Epoch 38/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.2191 - accuracy: 0.5415 - val_loss: 1.2988 - val_accuracy: 0.4950
# Epoch 39/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.2253 - accuracy: 0.5373 - val_loss: 1.2350 - val_accuracy: 0.5355
# Epoch 40/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.2176 - accuracy: 0.5401 - val_loss: 1.2858 - val_accuracy: 0.4943
# Epoch 41/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.2096 - accuracy: 0.5464 - val_loss: 1.2667 - val_accuracy: 0.5270
# Epoch 42/70
# 358/358 [==============================] - 35s 97ms/step - loss: 1.2147 - accuracy: 0.5378 - val_loss: 1.1830 - val_accuracy: 0.5469
# Epoch 43/70
# 358/358 [==============================] - 36s 101ms/step - loss: 1.2157 - accuracy: 0.5423 - val_loss: 1.1211 - val_accuracy: 0.5632
# Epoch 44/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.1987 - accuracy: 0.5517 - val_loss: 1.2409 - val_accuracy: 0.5312
# Epoch 45/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.1912 - accuracy: 0.5567 - val_loss: 1.2280 - val_accuracy: 0.5192
# Epoch 46/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.2114 - accuracy: 0.5441 - val_loss: 1.2257 - val_accuracy: 0.5398
# Epoch 47/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.1967 - accuracy: 0.5554 - val_loss: 1.2274 - val_accuracy: 0.5277
# Epoch 48/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.2001 - accuracy: 0.5491 - val_loss: 1.1541 - val_accuracy: 0.5639
# Epoch 49/70
# 358/358 [==============================] - 35s 97ms/step - loss: 1.1895 - accuracy: 0.5557 - val_loss: 1.1447 - val_accuracy: 0.5589
# Epoch 50/70
# 358/358 [==============================] - 35s 96ms/step - loss: 1.1891 - accuracy: 0.5520 - val_loss: 1.2838 - val_accuracy: 0.5007
# Epoch 51/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.1876 - accuracy: 0.5500 - val_loss: 1.1341 - val_accuracy: 0.5760
# Epoch 52/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.1820 - accuracy: 0.5512 - val_loss: 1.3380 - val_accuracy: 0.4815
# Epoch 53/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.1805 - accuracy: 0.5577 - val_loss: 1.0930 - val_accuracy: 0.5668
# Epoch 54/70
# 358/358 [==============================] - 34s 95ms/step - loss: 1.1830 - accuracy: 0.5559 - val_loss: 1.1605 - val_accuracy: 0.5526
# Epoch 55/70
# 358/358 [==============================] - 34s 94ms/step - loss: 1.1742 - accuracy: 0.5605 - val_loss: 1.1822 - val_accuracy: 0.5391
# Epoch 56/70
# 358/358 [==============================] - 34s 94ms/step - loss: 1.1699 - accuracy: 0.5597 - val_loss: 1.2277 - val_accuracy: 0.5398
# Epoch 57/70
# 358/358 [==============================] - 33s 93ms/step - loss: 1.1608 - accuracy: 0.5674 - val_loss: 1.1232 - val_accuracy: 0.5746
# Epoch 58/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.1488 - accuracy: 0.5691 - val_loss: 1.2017 - val_accuracy: 0.5305
# Epoch 59/70
# 358/358 [==============================] - 37s 102ms/step - loss: 1.1499 - accuracy: 0.5669 - val_loss: 1.0974 - val_accuracy: 0.5852
# Epoch 60/70
# 358/358 [==============================] - 35s 99ms/step - loss: 1.1451 - accuracy: 0.5656 - val_loss: 1.4408 - val_accuracy: 0.4652
# Epoch 61/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.1617 - accuracy: 0.5648 - val_loss: 1.1500 - val_accuracy: 0.5675
# Epoch 62/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.1513 - accuracy: 0.5662 - val_loss: 1.1326 - val_accuracy: 0.5689
# Epoch 63/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.1482 - accuracy: 0.5684 - val_loss: 1.1545 - val_accuracy: 0.5575
# Epoch 64/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.1508 - accuracy: 0.5703 - val_loss: 1.1591 - val_accuracy: 0.5753
# Epoch 65/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.1376 - accuracy: 0.5788 - val_loss: 1.1379 - val_accuracy: 0.5696
# Epoch 66/70
# 358/358 [==============================] - 35s 98ms/step - loss: 1.1380 - accuracy: 0.5735 - val_loss: 1.1830 - val_accuracy: 0.5490
# Epoch 67/70
# 358/358 [==============================] - 34s 96ms/step - loss: 1.1401 - accuracy: 0.5732 - val_loss: 1.1343 - val_accuracy: 0.5661
# Epoch 68/70
# 358/358 [==============================] - 36s 100ms/step - loss: 1.1226 - accuracy: 0.5872 - val_loss: 1.1107 - val_accuracy: 0.5795
# Epoch 69/70
# 358/358 [==============================] - 34s 94ms/step - loss: 1.1432 - accuracy: 0.5736 - val_loss: 1.2241 - val_accuracy: 0.5291
# Epoch 70/70
# 358/358 [==============================] - 35s 97ms/step - loss: 1.1263 - accuracy: 0.5802 - val_loss: 1.1320 - val_accuracy: 0.5689

# %%
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()
